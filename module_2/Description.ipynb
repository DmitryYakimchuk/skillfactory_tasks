# %% [markdown]
# # Описание для проекта № 2

# %% [markdown]
# ## Цель проекта
# провести разведовательный анализ данных, определив влияния условий жизни учащихся на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.
# ### Задачи:
# 1. Провести первичную обработку данных
# 2. Посмотреть на распределение признака для числовых переменных, устранить выбросы.
# 3. Оценить количество уникальных значений для номинативных переменных.
# 4. По необходимости преобразовать данные
# 5. Провести корреляционный анализ количественных переменных
# 6. Отобрать не коррелирующие переменные
# 7. Проанализировать номинативные переменные и устраните те, которые не влияют на предсказываемую величину — на переменную score
# 8. Сформулировать выводы относительно качества данных и тех переменных, которые будут использоваться в дальнейшем построении модели.

# %% [markdown]
# ## Краткая информация о данных
# Исходные данные находятся в виде 30 столбцов, к 29 из которых присутствуют описания. Большинство данных – это номинативные признаки.

# %% [markdown]
# ## Этапы работы над проектом
# 1. Просмотреть данные
# 2. Выявить степень заполненности всех колонок
# 3. Заполнить пустоты и устранить выбросы в целевой переменной score
# 4. По отдельности проанализировать номинатинвные переменные и устранить выбросы
# 5. Поискать статистически значимые различия в номинативных переменных
# 6. Заполнить пустоты в номинативных переменных
# 7. Проанализировать количественные признаки с применением корреляционного анализа
# 8. Устранить выбросы и пустые значения и заново провести корреляционный анализ
# 9. Сделать вывод о степени корреляции
# 10. Отметить итоги проведенного разведовательного анализа

# %% [markdown]
# ## Ответы на вопросы саморефлексии:
#
# 1. Какова была ваша роль в команде?
# *В какой команде?)*
#
#
# 2. Какой частью своей работы вы остались особенно довольны?
# *В этот раз такого нет*
#
# 3. Что не получилось сделать так, как хотелось? Над чем ещё стоит поработать?
# *Определить статистически значимые различия для номинативных переменных*
#
# 4. Что интересного и полезного вы узнали в этом модуле?
# *Статистика сама по себе. Кроме того интересный модуль numpy для работы с большими массивами числовых данных*
#
# 5. Что является вашим главным результатом при прохождении этого проекта?
# *Значимого результата пока отметить не могу*
#
# 6. Какие навыки вы уже можете применить в текущей деятельности?
# *Навык работы с большими массивами числовых данных в numpy*
#
# 7. Планируете ли вы дополнительно изучать материалы по теме проекта?
# *Да*
