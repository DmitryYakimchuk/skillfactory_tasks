# %% [markdown]
# # Задачи проекта:
#
# → Внимательно изучить детали каждой отдельной задачи.
#
# → Прочитать советы по выполнению проекта.
#
# → Ознакомиться с дополнительным материалом в модуле.
#
# → Скачать датасет и ноутбук-шаблон.
#
# → Ответить на все вопросы по этому датасету и набрать минимум 22 балла.
#
# → Загрузить ноутбук с решением на git, оформив его соответствующим образом.
#
# → Сдать проект на проверку.
#
# → Получить обратную связь от команды курса.

# %% [markdown]
# # Количество набранных в викторине баллов
# 27

# %% [markdown]
# # Ответы на вопросы саморефлексии

# %% [markdown]
# ## 1. Какой частью своей работы вы остались особенно довольны?
# Группировкой таблиц

# %% [markdown]
# ## 2. Что не получилось сделать так, как хотелось? Над чем ещё стоит поработать?
# Не получилось самому придумать рабочее решение к 27 задаче. Код взял из slack

# %% [markdown]
# ## 3. Что интересного и полезного вы узнали в этом модуле?
# Работать с большим объемом информации проще, предварительно выделив из него малую часть и отработав на ней необходимые операции

# %% [markdown]
# ## 4. Что является вашим главным результатом при прохождении этого проекта?
# Научился извлекать и обрабатывать данные из файлов, что уже помогло мне на текущей работе

# %% [markdown]
# ## 5. Планируете ли вы менять стратегию изучения последующих модулей?
# Для ближайших модулей точно нет.
